# %%
import pandas as pd

df=pd.read_excel('filtered_data_los angles _zip.xlsx')

# %%
# Get the unique zip codes from the DataFrame
unique_zip_codes = df['Zip Code'].unique()

# Print the unique zip codes
print(unique_zip_codes)
# Out:
# [90001 90002 90003 90004 90005 90006 90007 90008 90009 90010 90011 90012
#  90013 90014 90015 90016 90017 90018 90019 90020 90021 90022 90023 90024
#  90025 90026 90027 90028 90029 90030 90031 90032 90033 90034 90035 90036
#  90037 90038 90039 90040 90041 90042 90043 90044 90045 90046 90047 90048
#  90049 90050 90051 90052 90053 90054 90055 90056 90057 90058 90059 90060
#  90061 90062 90063 90064 90065 90066 90067 90068 90069 90070 90071 90072
#  90073 90074 90075 90076 90077 90078 90079 90080 90081 90082 90083 90084
#  90086 90087 90088 90089 90090 90091 90093 90094 90095 90096 90099 90102
#  90103 90201 90202 90209 90210 90211 90212 90213 90220 90221 90222 90223
#  90224 90230 90231 90232 90233 90239 90240 90241 90242 90245 90247 90248
#  90249 90250 90251 90254 90255 90260 90261 90262 90263 90264 90265 90266
#  90267 90270 90272 90274 90275 90277 90278 90280 90290 90291 90292 90293
#  90294 90295 90296 90301 90302 90303 90304 90305 90306 90307 90308 90309
# ...

# %%
# Get the unique zip codes from the DataFrame
unique_zip_codes = df['Zip Code'].unique()

# Print the unique zip codes
print(unique_zip_codes)

# Get the total number of unique zip codes
total_unique_zip_codes = len(unique_zip_codes)

# Print the total number of unique zip codes
print(total_unique_zip_codes)
# Out:
# [90001 90002 90003 90004 90005 90006 90007 90008 90009 90010 90011 90012
#  90013 90014 90015 90016 90017 90018 90019 90020 90021 90022 90023 90024
#  90025 90026 90027 90028 90029 90030 90031 90032 90033 90034 90035 90036
#  90037 90038 90039 90040 90041 90042 90043 90044 90045 90046 90047 90048
#  90049 90050 90051 90052 90053 90054 90055 90056 90057 90058 90059 90060
#  90061 90062 90063 90064 90065 90066 90067 90068 90069 90070 90071 90072
#  90073 90074 90075 90076 90077 90078 90079 90080 90081 90082 90083 90084
#  90086 90087 90088 90089 90090 90091 90093 90094 90095 90096 90099 90102
#  90103 90201 90202 90209 90210 90211 90212 90213 90220 90221 90222 90223
#  90224 90230 90231 90232 90233 90239 90240 90241 90242 90245 90247 90248
#  90249 90250 90251 90254 90255 90260 90261 90262 90263 90264 90265 90266
#  90267 90270 90272 90274 90275 90277 90278 90280 90290 90291 90292 90293
#  90294 90295 90296 90301 90302 90303 90304 90305 90306 90307 90308 90309
# ...

# %%
# Get the unique zip codes from the DataFrame
unique_zip_codes = df['Zip Code'].unique()

# Convert the unique zip codes array to a DataFrame
unique_zip_codes_df = pd.DataFrame(unique_zip_codes, columns=['Unique Zip Codes'])

# Print the unique zip codes in one column
print(unique_zip_codes_df)
# Out:
#      Unique Zip Codes
# 0               90001
# 1               90002
# 2               90003
# 3               90004
# 4               90005
# ..                ...
# 482             93584
# 483             93586
# 484             93590
# 485             93591
# 486             93599
#
# [487 rows x 1 columns]

# %%
# Save the unique zip codes to an Excel file
unique_zip_codes_df.to_excel('unique_zip_codes_LosAnglesDMV2018.xlsx', index=False)
