# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
source_type = ['Combination Long-haul Truck (CNG)', 'Combination Long-haul Truck (Diesel)',
               'Light Commercial Truck (CNG)', 'Light Commercial Truck (Diesel)', 'Light Commercial Truck (Gasoline)',
               'Other Buses (Diesel)', 'Passenger Car (Diesel)', 'Passenger Car (Electricity)', 'Passenger Car (Ethanol)',
               'Passenger Car (Gasoline)', 'Passenger Truck (Diesel)', 'Passenger Truck (Ethanol)', 'Passenger Truck (Gasoline)',
               'Refuse Truck (Diesel)', 'Single Unit Short-haul Truck (CNG)', 'Single Unit Short-haul Truck (Diesel)',
               'Transit Bus (CNG)']

vehicle_numbers = [405, 636, 102, 1371, 421, 24, 364, 20983, 4393, 346634, 728, 252, 4249, 25, 111, 357, 60]

# Plotting the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=vehicle_numbers, y=source_type, palette='viridis')
plt.xlabel('Number of Vehicles')
plt.ylabel('Source Type Name / Make')
plt.title('Vehicle Numbers by Source Type')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
source_type = ['Combination Long-haul Truck (CNG)', 'Combination Long-haul Truck (Diesel)',
               'Light Commercial Truck (CNG)', 'Light Commercial Truck (Diesel)', 'Light Commercial Truck (Gasoline)',
               'Other Buses (Diesel)', 'Passenger Car (Diesel)', 'Passenger Car (Electricity)', 'Passenger Car (Ethanol)',
               'Passenger Car (Gasoline)', 'Passenger Truck (Diesel)', 'Passenger Truck (Ethanol)', 'Passenger Truck (Gasoline)',
               'Refuse Truck (Diesel)', 'Single Unit Short-haul Truck (CNG)', 'Single Unit Short-haul Truck (Diesel)',
               'Transit Bus (CNG)']

vehicle_numbers = [405, 636, 102, 1371, 421, 24, 364, 20983, 4393, 346634, 728, 252, 4249, 25, 111, 357, 60]

# Plotting the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=vehicle_numbers, y=source_type, palette='viridis')
plt.xlabel('Number of Vehicles')
plt.ylabel('Source Type Name / Make')
plt.title('Vehicle Numbers by Source Type')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Rearranged data
source_type = ['Other Buses (Diesel)', 'Refuse Truck (Diesel)', 'Transit Bus (CNG)', 'Light Commercial Truck (CNG)',
               'Single Unit Short-haul Truck (CNG)', 'Passenger Truck (Ethanol)', 'Single Unit Short-haul Truck (Diesel)',
               'Passenger Car (Diesel)', 'Combination Long-haul Truck (CNG)', 'Light Commercial Truck (Gasoline)',
               'Combination Long-haul Truck (Diesel)', 'Passenger Truck (Diesel)', 'Light Commercial Truck (Diesel)',
               'Passenger Truck (Gasoline)', 'Passenger Car (Ethanol)', 'Passenger Car (Electricity)',
               'Passenger Car (Gasoline)']

vehicle_numbers = [24, 25, 60, 102, 111, 252, 357, 364, 405, 421, 636, 728, 1371, 4249, 4393, 20983, 346634]

# Plotting the bar chart with fancy features
plt.figure(figsize=(10, 12))
sns.barplot(x=source_type, y=vehicle_numbers, palette='viridis')
plt.ylabel('Number of Vehicles', fontsize=14)
plt.xlabel('Source Type Name / Make', fontsize=14)
plt.title('Vehicle Numbers by Source Type', fontsize=16)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adding annotations to the bars
for index, value in enumerate(vehicle_numbers):
    plt.text(index, value + 50, f"{value}", ha='center', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Rearranged data
source_type = ['Other Buses (Diesel)', 'Refuse Truck (Diesel)', 'Transit Bus (CNG)', 'Light Commercial Truck (CNG)',
               'Single Unit Short-haul Truck (CNG)', 'Passenger Truck (Ethanol)', 'Single Unit Short-haul Truck (Diesel)',
               'Passenger Car (Diesel)', 'Combination Long-haul Truck (CNG)', 'Light Commercial Truck (Gasoline)',
               'Combination Long-haul Truck (Diesel)', 'Passenger Truck (Diesel)', 'Light Commercial Truck (Diesel)',
               'Passenger Truck (Gasoline)', 'Passenger Car (Ethanol)', 'Passenger Car (Electricity)',
               'Passenger Car (Gasoline)']

vehicle_numbers = [24, 25, 60, 102, 111, 252, 357, 364, 405, 421, 636, 728, 1371, 4249, 4393, 20983, 346634]

# Plotting the bar chart with blue shade
plt.figure(figsize=(10, 12))
sns.barplot(x=source_type, y=vehicle_numbers, palette='Blues_r')  # Use 'Blues_r' for a reversed blue shade palette
plt.ylabel('Number of Vehicles', fontsize=14)
plt.xlabel('Source Type Name / Make', fontsize=14)
plt.title('Vehicle Numbers by Source Type', fontsize=16)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adding annotations to the bars
for index, value in enumerate(vehicle_numbers):
    plt.text(index, value + 50, f"{value}", ha='center', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Rearranged data
source_type = ['Other Buses (Diesel)', 'Refuse Truck (Diesel)', 'Transit Bus (CNG)', 'Light Commercial Truck (CNG)',
               'Single Unit Short-haul Truck (CNG)', 'Passenger Truck (Ethanol)', 'Single Unit Short-haul Truck (Diesel)',
               'Passenger Car (Diesel)', 'Combination Long-haul Truck (CNG)', 'Light Commercial Truck (Gasoline)',
               'Combination Long-haul Truck (Diesel)', 'Passenger Truck (Diesel)', 'Light Commercial Truck (Diesel)',
               'Passenger Truck (Gasoline)', 'Passenger Car (Ethanol)', 'Passenger Car (Electricity)',
               'Passenger Car (Gasoline)']

vehicle_numbers = [24, 25, 60, 102, 111, 252, 357, 364, 405, 421, 636, 728, 1371, 4249, 4393, 20983, 346634]

# Plotting the bar chart with reversed blue shade
plt.figure(figsize=(10, 12))
sns.barplot(x=source_type, y=vehicle_numbers, palette='Blues')  # Use 'Blues' for the default blue shade palette
plt.ylabel('Number of Vehicles', fontsize=14)
plt.xlabel('Source Type Name / Make', fontsize=14)
plt.title('Vehicle Numbers by Source Type', fontsize=16)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adding annotations to the bars
for index, value in enumerate(vehicle_numbers):
    plt.text(index, value + 50, f"{value}", ha='center', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Modified data with "Passenger Car (Gasoline)" value scaled up
source_type = ['Other Buses (Diesel)', 'Refuse Truck (Diesel)', 'Transit Bus (CNG)', 'Light Commercial Truck (CNG)',
               'Single Unit Short-haul Truck (CNG)', 'Passenger Truck (Ethanol)', 'Single Unit Short-haul Truck (Diesel)',
               'Passenger Car (Diesel)', 'Combination Long-haul Truck (CNG)', 'Light Commercial Truck (Gasoline)',
               'Combination Long-haul Truck (Diesel)', 'Passenger Truck (Diesel)', 'Light Commercial Truck (Diesel)',
               'Passenger Truck (Gasoline)', 'Passenger Car (Ethanol)', 'Passenger Car (Electricity)',
               'Passenger Car (Gasoline)']

vehicle_numbers = [24, 25, 60, 102, 111, 252, 357, 364, 405, 421, 636, 728, 1371, 4249, 4393, 20983, 346634]
# Plotting the bar chart with reversed blue shade
plt.figure(figsize=(10, 8))  # Adjust the figure size
sns.barplot(x=vehicle_numbers, y=source_type, palette='Blues')  # Use 'Blues' for the default blue shade palette
plt.xlabel('Number of Vehicles', fontsize=14)
plt.ylabel('Source Type Name / Make', fontsize=14)
plt.title('Vehicle Numbers by Source Type', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adding annotations to the bars
for index, value in enumerate(vehicle_numbers):
    # For "Passenger Car (Gasoline)" bar, annotate with its actual value
    if source_type[index] == 'Passenger Car (Gasoline)':
        plt.text(value + 50, index, f"{value}", va='center', fontsize=10, color='black', fontweight='bold')
    else:
        plt.text(value + 50, index, f"{value}", va='center', fontsize=10, color='black')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Rearranged data
source_type = ['Other Buses (Diesel)', 'Refuse Truck (Diesel)', 'Transit Bus (CNG)', 'Light Commercial Truck (CNG)',
               'Single Unit Short-haul Truck (CNG)', 'Passenger Truck (Ethanol)', 'Single Unit Short-haul Truck (Diesel)',
               'Passenger Car (Diesel)', 'Combination Long-haul Truck (CNG)', 'Light Commercial Truck (Gasoline)',
               'Combination Long-haul Truck (Diesel)', 'Passenger Truck (Diesel)', 'Light Commercial Truck (Diesel)',
               'Passenger Truck (Gasoline)', 'Passenger Car (Ethanol)', 'Passenger Car (Electricity)',
               'Passenger Car (Gasoline)']

vehicle_numbers = [24, 25, 60, 102, 111, 252, 357, 364, 405, 421, 636, 728, 1371, 4249, 4393, 20983, 346634]

# Sort data in descending order
sorted_data = sorted(zip(vehicle_numbers, source_type), reverse=True)
vehicle_numbers, source_type = zip(*sorted_data)

# Plotting the bar chart with reversed blue shade
plt.figure(figsize=(10, 8))  # Adjust the figure size
sns.barplot(x=vehicle_numbers, y=source_type, palette='Blues')  # Use 'Blues' for the default blue shade palette
plt.xlabel('Number of Vehicles', fontsize=14)
plt.ylabel('Source Type Name / Make', fontsize=14)
plt.title('Vehicle Numbers by Source Type', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adding annotations to the bars
for index, value in enumerate(vehicle_numbers):
    # For "Passenger Car (Gasoline)" bar, annotate with its actual value
    if source_type[index] == 'Passenger Car (Gasoline)':
        plt.text(value + 50, index, f"{value}", va='center', fontsize=10, color='black', fontweight='bold')
    else:
        plt.text(value + 50, index, f"{value}", va='center', fontsize=10, color='black')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 20
#      18 # Plotting the bar chart with reversed blue shade
#      19 plt.figure(figsize=(10, 8))  # Adjust the figure size
# ---> 20 sns.barplot(x=vehicle_numbers, y=source_type, palette='Blues')  # Use 'Blues' for the default blue shade palette
#      21 plt.xlabel('Number of Vehicles', fontsize=14)
#      22 plt.ylabel('Source Type Name / Make', fontsize=14)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
# Data
source_type = ['Combination Long-haul Truck (CNG)', 'Combination Long-haul Truck (Diesel)',
               'Light Commercial Truck (CNG)', 'Light Commercial Truck (Diesel)', 'Light Commercial Truck (Gasoline)',
               'Other Buses (Diesel)', 'Passenger Car (Diesel)', 'Passenger Car (Electricity)', 'Passenger Car (Ethanol)',
               'Passenger Car (Gasoline)', 'Passenger Truck (Diesel)', 'Passenger Truck (Ethanol)', 'Passenger Truck (Gasoline)',
               'Refuse Truck (Diesel)', 'Single Unit Short-haul Truck (CNG)', 'Single Unit Short-haul Truck (Diesel)',
               'Transit Bus (CNG)']

vehicle_numbers = [405, 636, 102, 1371, 421, 24, 364, 20983, 4393, 346634, 728, 252, 4249, 25, 111, 357, 60]

# Sort data by vehicle_numbers in descending order
sorted_data = sorted(zip(vehicle_numbers, source_type), reverse=True)
vehicle_numbers, source_type = zip(*sorted_data)

# Print the data in descending order
for vehicle, source in zip(vehicle_numbers, source_type):
    print(f"{source}: {vehicle}")
# Out:
# Passenger Car (Gasoline): 346634
# Passenger Car (Electricity): 20983
# Passenger Car (Ethanol): 4393
# Passenger Truck (Gasoline): 4249
# Light Commercial Truck (Diesel): 1371
# Passenger Truck (Diesel): 728
# Combination Long-haul Truck (Diesel): 636
# Light Commercial Truck (Gasoline): 421
# Combination Long-haul Truck (CNG): 405
# Passenger Car (Diesel): 364
# Single Unit Short-haul Truck (Diesel): 357
# Passenger Truck (Ethanol): 252
# Single Unit Short-haul Truck (CNG): 111
# Light Commercial Truck (CNG): 102
# Transit Bus (CNG): 60
# Refuse Truck (Diesel): 25
# Other Buses (Diesel): 24

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
source_type = ['Passenger Car (Gasoline)', 'Passenger Car (Electricity)', 'Passenger Car (Ethanol)',
               'Passenger Truck (Gasoline)', 'Light Commercial Truck (Diesel)', 'Passenger Truck (Diesel)',
               'Combination Long-haul Truck (Diesel)', 'Light Commercial Truck (Gasoline)',
               'Combination Long-haul Truck (CNG)', 'Passenger Car (Diesel)', 'Single Unit Short-haul Truck (Diesel)',
               'Passenger Truck (Ethanol)', 'Single Unit Short-haul Truck (CNG)', 'Light Commercial Truck (CNG)',
               'Transit Bus (CNG)', 'Refuse Truck (Diesel)', 'Other Buses (Diesel)']

vehicle_numbers = [346634, 20983, 4393, 4249, 1371, 728, 636, 421, 405, 364, 357, 252, 111, 102, 60, 25, 24]

# Plotting the bar chart with reversed blue shade
plt.figure(figsize=(10, 8))
sns.barplot(x=vehicle_numbers, y=source_type, palette='Blues_r')  # Use 'Blues_r' for the reversed blue shade palette
plt.xlabel('Number of Vehicles', fontsize=14)
plt.ylabel('Source Type Name / Make', fontsize=14)
plt.title('Vehicle Numbers by Source Type', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adding annotations to the bars
for index, value in enumerate(vehicle_numbers):
    # For "Passenger Car (Gasoline)" bar, annotate with its actual value
    if source_type[index] == 'Passenger Car (Gasoline)':
        plt.text(value + 50, index, f"{value}", va='center', fontsize=10, color='black', fontweight='bold')
    else:
        plt.text(value + 50, index, f"{value}", va='center', fontsize=10, color='black')

plt.tight_layout()
plt.show()
